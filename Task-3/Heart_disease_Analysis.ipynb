# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart_disease_dataset.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      67    1   2       111   536    0        2       88      0      1.3
# 1      57    1   3       109   107    0        2      119      0      5.4
# 2      43    1   4       171   508    0        1      113      0      3.7
# 3      71    0   4        90   523    0        2      152      0      4.7
# 4      36    1   2       119   131    0        2      128      0      5.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 3064   52    0   1       169   479    0        0      124      0      3.7
# 3065   75    0   4        90   372    0        2      141      0      2.1
# 3066   68    1   4       166   564    0        1       76      0      4.5
# 3067   66    0   3       143   113    1        1      207      0      3.6
# 3068   38    1   4       100   507    0        1      187      0      0.9
#
#       slope  ca  thal  smoking  diabetes   bmi  heart_disease
# 0         3   2     3        1         0  23.4              0
# 1         2   0     3        0         1  35.4              0
# 2         3   0     7        1         1  29.9              0
# 3         2   1     3        1         0  15.2              1
# 4         3   1     3        1         0  16.7              1
# ...     ...  ..   ...      ...       ...   ...            ...
# 3064      2   3     3        0         0  27.8              0
# 3065      2   2     3        0         1  37.0              1
# 3066      3   1     3        0         0  16.1              0
# 3067      1   0     6        0         0  27.7              0
# 3068      1   0     7        0         0  16.3              0
#
# [3069 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3069 entries, 0 to 3068
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            3069 non-null   int64
#  1   sex            3069 non-null   int64
#  2   cp             3069 non-null   int64
#  3   trestbps       3069 non-null   int64
#  4   chol           3069 non-null   int64
#  5   fbs            3069 non-null   int64
#  6   restecg        3069 non-null   int64
#  7   thalach        3069 non-null   int64
#  8   exang          3069 non-null   int64
#  9   oldpeak        3069 non-null   float64
#  10  slope          3069 non-null   int64
#  11  ca             3069 non-null   int64
#  12  thal           3069 non-null   int64
#  13  smoking        3069 non-null   int64
#  14  diabetes       3069 non-null   int64
#  15  bmi            3069 non-null   float64
#  16  heart_disease  3069 non-null   int64
# dtypes: float64(2), int64(15)
# memory usage: 407.7 KB

# %%
df.describe()
# Out:
#               age          sex           cp     trestbps         chol  \
# count  3069.00000  3069.000000  3069.000000  3069.000000  3069.000000
# mean     52.50114     0.555556     2.489736   145.306289   347.219941
# std      13.70752     0.496985     1.110417    31.602321   146.853319
# min      29.00000     0.000000     1.000000    90.000000   100.000000
# 25%      41.00000     0.000000     2.000000   118.000000   215.000000
# 50%      53.00000     1.000000     2.000000   146.000000   350.000000
# 75%      64.00000     1.000000     3.000000   172.000000   475.000000
# max      76.00000     1.000000     4.000000   200.000000   600.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  3069.000000  3069.000000  3069.000000  3069.000000  3069.000000
# mean      0.145650     1.004236   135.157380     0.176279     3.189052
# std       0.352813     0.812016    43.353197     0.381119     1.802815
# min       0.000000     0.000000    60.000000     0.000000     0.000000
# 25%       0.000000     0.000000    98.000000     0.000000     1.600000
# 50%       0.000000     1.000000   135.000000     0.000000     3.200000
# 75%       0.000000     2.000000   172.000000     0.000000     4.700000
# max       1.000000     2.000000   210.000000     1.000000     6.200000
#
#              slope           ca         thal      smoking     diabetes  \
# count  3069.000000  3069.000000  3069.000000  3069.000000  3069.000000
# mean      2.023786     0.626588     4.544477     0.348974     0.193874
# std       0.817679     0.891447     1.751064     0.476723     0.395396
# min       1.000000     0.000000     3.000000     0.000000     0.000000
# 25%       1.000000     0.000000     3.000000     0.000000     0.000000
# 50%       2.000000     0.000000     3.000000     0.000000     0.000000
# 75%       3.000000     1.000000     6.000000     1.000000     0.000000
# max       3.000000     3.000000     7.000000     1.000000     1.000000
#
#                bmi  heart_disease
# count  3069.000000    3069.000000
# mean     27.496839       0.403715
# std       7.281731       0.490721
# min      15.000000       0.000000
# 25%      21.300000       0.000000
# 50%      27.400000       0.000000
# 75%      33.900000       1.000000
# max      40.000000       1.000000

# %%
df.isnull().sum()
# Out:
# age              0
# sex              0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# smoking          0
# diabetes         0
# bmi              0
# heart_disease    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (3069, 17)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'smoking', 'diabetes', 'bmi',
#        'heart_disease'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                int64
# sex                int64
# cp                 int64
# trestbps           int64
# chol               int64
# fbs                int64
# restecg            int64
# thalach            int64
# exang              int64
# oldpeak          float64
# slope              int64
# ca                 int64
# thal               int64
# smoking            int64
# diabetes           int64
# bmi              float64
# heart_disease      int64
# dtype: object

# %% [markdown]
# # Data Visualizations

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="heart_disease", hue="heart_disease", palette="coolwarm", legend=False)
plt.title("Heart Disease Distribution")
plt.xlabel("Heart Disease (0 = no 1 = yes")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.violinplot(data=df, x="heart_disease", y="age", hue="heart_disease", palette="coolwarm", legend=False)
plt.title("Age Distribution by Heart Disease (Violin Plot)")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="sex", hue="heart_disease", palette="coolwarm")
plt.title("Sex vs Heart Disease")
plt.xlabel("Sex (0 = Female, 1 = Male)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="heart_disease", y="trestbps", hue="heart_disease", palette="coolwarm", legend=False)
plt.title("Resting Blood Pressure vs Heart Disease")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Resting Blood Pressure (trestbps)")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x="cp", hue="heart_disease", palette="coolwarm")
plt.title("Chest Pain Type vs Heart Disease")
plt.xlabel("Chest Pain Type (0-3)")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="heart_disease", y="chol", hue="heart_disease", palette="coolwarm", legend=False)
plt.title("Cholesterol Levels vs Heart Disease")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Cholesterol (chol)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="fbs", hue="heart_disease", palette="coolwarm")
plt.title("Fasting Blood Sugar vs Heart Disease")
plt.xlabel("FBS > 120 mg/dl (0 = No, 1 = Yes)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="restecg", hue="heart_disease", palette="coolwarm")
plt.title("Resting ECG Results vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="heart_disease", y="thalach", hue="heart_disease", palette="coolwarm")
plt.title("Maximum Heart Rate vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="exang", hue="heart_disease", palette="coolwarm")
plt.title("Exercise Induced Angina vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="heart_disease", y="oldpeak", hue="heart_disease", palette="coolwarm")
plt.title("ST Depression vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="slope", hue="heart_disease", palette="coolwarm")
plt.title("Slope of ST Segment vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="ca", hue="heart_disease", palette="coolwarm")
plt.title("Number of Major Vessels vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="thal", hue="heart_disease", palette="coolwarm")
plt.title("Thalassemia Type vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="smoking", hue="heart_disease", palette="coolwarm")
plt.title("Smoking vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="diabetes", hue="heart_disease", palette="coolwarm")
plt.title("Diabetes vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="heart_disease", y="bmi",hue="heart_disease", palette="coolwarm")
plt.title("BMI vs Heart Disease")
plt.show()

# %%
plt.figure(figsize=(12,8))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Features")
plt.show()
